# %% [markdown]
# <a href="https://colab.research.google.com/github/guupiii/ESAA/blob/main/ESAA_YB_11_2_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. 주제 및 데이터**
#
# 칼로리 소모량 회귀 예측 ai 해커톤
#
# 체중, 성별, 운동기간, 심박수 등 생체 데이터를 기반으로 칼로리 소모량을 예측한다.
#
# 주제 : 생체 데이터로부터 칼로리 소모량을 예측하는 ai 알고리즘 개발
#
# **2. 코드 리뷰**
#
# (1) 전처리
#
# - PolynomialFeatures를 적용해 다항식 기반의 새로운 변수 생성
#
# - 데이터 정규화, 표준화 대신에 피처 조합에 집중
#
# - 예측값을 반올림으로 후처리하여 성능을 개선함
#
#
# (2) 모델링
#
# - 최종적으로 앙상블 기반 구조 선택
#
# - 복잡한 멀티 모델 태스킹이 아닌 단, 다중 모델을 변형시킨 조합으로 점수를 올렸다
#
# - 다항 feature의 degree를 조절하여 시험해보았으나 과도한 차수는 오히려 성능 하락을 유발했음
#
#
# **3. 차별점 및 배울 점**
#
# - PolynomialFeatures 를 이용한 특성 확장에 집중하였음.
#
# - 적절한 다항 차수를 직접 실험해 최적 지점을 찾아가는 과정
#
# - 반올림 등의 후처리 과정도 점수를 크게 올릴 수 있다.
#
# - 머신러닝 대회에서는 리더보드 점수 중심의 최적화가 우선될 수 있다.
